# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # first ml algo

# %%
 from sklearn.tree import DecisionTreeClassifier

# %%
features = [[150,0],[170,0],[130,1],[120,1]] #[weight(grams),color] color =0=red, 1=orange

# %%
labels =["apple","apple","orange","orange"]
# train a model
clf = DecisionTreeClassifier()
clf=clf.fit(features , labels)

# %% [markdown]
# # model i ready to predict

# %%
prediction=clf.predict([[120,1],[34,0],[670,0]]) #its storing in an array

# %%
 print(f"the fruit is {prediction[0]}") # accesing array of reulsts
# Out:
# the fruit is orange

# %%
 print(f"the fruit is {prediction}")
# Out:
# the fruit is ['orange' 'apple' 'apple']

# %% [markdown]
#  # second ml algo for obesity

# %%
from sklearn.tree import DecisionTreeClassifier

# Your logical data
cal   = [[2000],[30],[1000],[1500]]   # Calories
ex    = [[60],[5],[30],[45]]         # Exercise
label = ["good","sad","better","ok"] # Target labels

# ✅ Combine calories & exercise column-wise
features = [[c[0], e[0]] for c, e in zip(cal, ex)]
# features becomes: [[2000,60],[30,5],[1000,30],[1500,45]]

# Train a simple decision tree
model = DecisionTreeClassifier()
model.fit(features, label)

# Try a new prediction
 # [Calories, Exercise]
clf1=model.predict(new_person)
print(f"Prediction:{clf1}")
# Out:
# Prediction:['better']

# %%
new_person=[[200,20]]

# %%
clf1
# Out:
# array(['ok'], dtype='<U6')

# %%
from sklearn.tree import plot_tree

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6000))

# %%
plot_tree(clf,feature_names=["weight","color"],class_names=["apple","orange"] , filled=True)
# Out:
# [Text(0.5, 0.75, 'color <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = apple'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = apple'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = orange'),
#  Text(0.625, 0.5, '  False')]

# %%
import numpy as np, pandas as pd

np.random.seed(42)
n = 100000
preg = np.random.poisson(1.8, n).clip(0,17).astype(int)
age = np.random.randint(21,90,n)
glucose = np.random.normal(120,30,n).clip(50,200)
bp = np.random.normal(70,12,n).clip(40,122)
skin = np.random.normal(20,10,n).clip(0,99)
insulin = np.clip(glucose*2.5 + np.random.normal(0,80,n),0,846)
bmi = np.clip(np.random.normal(30,7,n)+0.02*(age-40)+0.01*(glucose-120)+np.random.normal(0,2,n),15,60)
ped = np.random.beta(1.5,10,n)*2.5

score = (0.0008*glucose**2 + 0.002*bmi**2 + 0.01*preg*glucose
         -0.03*bp + 0.5*np.tanh((np.log1p(insulin)-4)/2)
         +0.6*ped)
prob = 1/(1+np.exp(-(score-10)/3))
outcome = (np.random.rand(n) < prob).astype(int)

data = pd.DataFrame({
    "Pregnancies": preg, "Glucose": glucose.round(2), "BloodPressure": bp.round(2),
    "SkinThickness": skin.round(2), "Insulin": insulin.round(2), "BMI": bmi.round(2),
    "DiabetesPedigree": ped.round(4), "Age": age, "Outcome": outcome
})
data.to_csv("synthetic_diabetes_100k.csv", index=False)
print("Saved synthetic_diabetes.csv")
# Out:
# Saved synthetic_diabetes.csv

# %%
import numpy as np, pandas as pd

np.random.seed(42)
n = 100000
preg = np.random.poisson(1.8, n).clip(0,17).astype(int)
age = np.random.randint(21,90,n)
glucose = np.random.normal(120,30,n).clip(50,200)
bp = np.random.normal(70,12,n).clip(40,122)
skin = np.random.normal(20,10,n).clip(0,99)
insulin = np.clip(glucose*2.5 + np.random.normal(0,80,n),0,846)
bmi = np.clip(np.random.normal(30,7,n)+0.02*(age-40)+0.01*(glucose-120)+np.random.normal(0,2,n),15,60)
ped = np.random.beta(1.5,10,n)*2.5

score = (0.0008*glucose**2 + 0.002*bmi**2 + 0.01*preg*glucose
         -0.03*bp + 0.5*np.tanh((np.log1p(insulin)-4)/2)
         +0.6*ped)
prob = 1/(1+np.exp(-(score-10)/3))
outcome = (np.random.rand(n) < prob).astype(int)

data = pd.DataFrame({
    "Pregnancies": preg, "Glucose": glucose.round(2), "BloodPressure": bp.round(2),
    "SkinThickness": skin.round(2), "Insulin": insulin.round(2), "BMI": bmi.round(2),
    "DiabetesPedigree": ped.round(4), "Age": age, "Outcome": outcome
})
data.to_csv("diabetes.csv", index=False)
print("Saved diabetes.csv")
# Out:
# Saved diabetes.csv

# %%
import numpy as np
import pandas as pd


rolls = list(range(1,101))
name =[f"student{i}" for i in range  (1,101)]
ages=[19]*100
branches = np.random.choice(["CSE","AIML","AIDS","CIVIL","MECH","ENTC"],size=100)
GPA=np.round(np.random.uniform(6.5,10,size=100),2)
absent =np.random.poisson(lam=3,size=100)
liblary_visits=np.random.poisson(lam=4,size=100)

data ={
    "ROLL_NO":rolls,
    "NAMES":name,
    "AGE":ages,
    "BRANCH":branches,
    "CGPA":GPA,
    "ABSENCES":absent,
    "LIBRARY_VISITS":liblary_visits
}
df=pd.DataFrame(data)
df.to_csv("student_data(100).csv",index=False)
print("saved")
# Out:
# saved

# %%
# code

# %% [markdown]
# # training on iris datasets

# %%
import pandas as pd

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
data= pd.read_excel("iris.xlsx")

# %%
data.head()
# Out:
#    slength  sepalwidth  petallength  petalwidth           class
# 0      7.9         2.8          5.6         2.2  Iris-virginica
# 1      7.7         2.6          6.9         2.3  Iris-virginica
# 2      7.7         3.4          5.6         2.4  Iris-virginica
# 3      7.7         2.2          5.0         1.5  Iris-virginica
# 4      7.7         2.7          4.9         1.8  Iris-virginica

# %%
  x = data.iloc[:,:-1] # rows all from data but not include last coloumn

# %%
x
# Out:
#      slength  sepalwidth  petallength  petalwidth
# 0        7.9         2.8          5.6         2.2
# 1        7.7         2.6          6.9         2.3
# 2        7.7         3.4          5.6         2.4
# 3        7.7         2.2          5.0         1.5
# 4        7.7         2.7          4.9         1.8
# ..       ...         ...          ...         ...
# 111      4.4         3.5          1.6         0.2
# 112      4.4         3.4          1.5         0.6
# 113      4.4         3.1          1.5         0.2
# 114      4.3         4.0          1.2         0.1
# 115      NaN         NaN          NaN         0.2
#
# [116 rows x 4 columns]

# %%
y=data.iloc[:,-1]

# %%
y
# Out:
# 0      Iris-virginica
# 1      Iris-virginica
# 2      Iris-virginica
# 3      Iris-virginica
# 4      Iris-virginica
#             ...
# 111       Iris-setosa
# 112       Iris-setosa
# 113       Iris-setosa
# 114       Iris-setosa
# 115               NaN
# Name: class, Length: 116, dtype: object

# %%
model = RandomForestClassifier() # selected the model

# %%
data = data.dropna()

# %%
print(data.isnull().sum())
# Out:
# slength        0
# sepalwidth     0
# petallength    0
# petalwidth     0
# class          0
# dtype: int64

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# Load data
data = pd.read_excel("iris.xlsx")

# Check for NaN values
print(data.isnull().sum())

# Option 1: Drop missing rows
data = data.dropna()

# OR Option 2: Fill missing values (imputation)
# data = data.fillna(data.mean(numeric_only=True))

# Split features and target
x = data.iloc[:, :-1]   # all columns except last
y = data.iloc[:, -1]    # last column

# Create and fit the model
model = RandomForestClassifier()
model.fit(x, y)

print("Model trained successfully!")
# Out:
# slength        1
# sepalwidth     1
# petallength    1
# petalwidth     1
# class          1
# dtype: int64
# Model trained successfully!

# %%
data = data.dropna(subset=[data.columns[-1]])

# %%
model.fit(x, y)
# Out:
# RandomForestClassifier()

# %%
model = RandomForestClassifier()
model.fit(x.values, y.values)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
predictions = model.predict([[7.9,2.8,5.6,2.2]])

# %%
predictions
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
predictions1 = model.predict([[ 5	,3,	6,	1.8
]])

# %%
predictions1
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
data1 = pd.read_excel("iris-test.xlsx")

# %%
x_test=data1.iloc[:,:-1]
y_test=data1.iloc[:,-1]

# %%
predictions=model.predict (x_test.values)

# %%
 predictions
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa'], dtype=object)
